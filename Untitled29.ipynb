# %% [markdown]
# <a href="https://colab.research.google.com/github/IndreshYadav003/Questions-Placement/blob/main/Untitled29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
array=[2,4,6,8,2,1,0,-5,44,5]
min=array[0]
for i in range(len(array)):
    if array[i]<min:
        min=array[i]
print(min)#-5
#tc=O(n)
# Out:
# -5
